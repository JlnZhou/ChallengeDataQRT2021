# %% [markdown]
# # QRT Challenge Data 2021
#
# ## Summary
#
# The aim of the 2021 QRT Challenge Data is to determine the link between two types of assets: liquids and illiquids. We provide returns of 100 illiquid assets and the aim is to predict, for the same day, the sign of the return of 100 liquid assets.

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# ## Loading the data

# %%
X_train = pd.read_csv('../ChallengeDataQRT2021Data/X_train_itDkypA.csv', index_col = 0)
Y_train = pd.read_csv('../ChallengeDataQRT2021Data/y_train_3LeeT2g.csv', index_col = 0)
X_test = pd.read_csv('../ChallengeDataQRT2021Data/X_test_Beg4ey3.csv', index_col = 0)

# %%
X_train.head()
# Out:
#     ID_DAY   RET_216   RET_238    RET_45  RET_295  RET_230   RET_120  \
# ID
# 0     3316  0.004024  0.009237  0.004967      NaN  0.01704  0.013885
# 1     3316  0.004024  0.009237  0.004967      NaN  0.01704  0.013885
# 2     3316  0.004024  0.009237  0.004967      NaN  0.01704  0.013885
# 3     3316  0.004024  0.009237  0.004967      NaN  0.01704  0.013885
# 4     3316  0.004024  0.009237  0.004967      NaN  0.01704  0.013885
#
#      RET_188   RET_260    RET_15  ...   RET_122  RET_194    RET_72   RET_293  \
# ID                                ...
# 0   0.041885  0.015207 -0.003143  ...  0.007596  0.01501  0.014733 -0.000476
# 1   0.041885  0.015207 -0.003143  ...  0.007596  0.01501  0.014733 -0.000476
# 2   0.041885  0.015207 -0.003143  ...  0.007596  0.01501  0.014733 -0.000476
# 3   0.041885  0.015207 -0.003143  ...  0.007596  0.01501  0.014733 -0.000476
# 4   0.041885  0.015207 -0.003143  ...  0.007596  0.01501  0.014733 -0.000476
#
#      RET_281   RET_193    RET_95   RET_162   RET_297  ID_TARGET
# ID
# 0   0.006539 -0.010233  0.001251 -0.003102 -0.094847        139
# 1   0.006539 -0.010233  0.001251 -0.003102 -0.094847        129
# 2   0.006539 -0.010233  0.001251 -0.003102 -0.094847        136
# 3   0.006539 -0.010233  0.001251 -0.003102 -0.094847        161
# 4   0.006539 -0.010233  0.001251 -0.003102 -0.094847        217
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Reshaping the data
#
# We transform the data so that each line corresponds to a specific day

# %%
idx_ret_features = np.where(X_train.columns.str.contains('RET'))[0]
init_ret_features = X_train.columns[idx_ret_features]
target_ret_features = ['RET_' + str(a) for a in X_train['ID_TARGET'].unique()]

# %%
returns = {}
for day in tqdm(X_train.ID_DAY.unique()):
    u = X_train.loc[X_train.ID_DAY == day]
    a = u.iloc[0, idx_ret_features]
    b = Y_train[X_train.ID_DAY == day]['RET_TARGET']
    b.index = ['RET_' + str(a) for a in u.ID_TARGET]
    returns[day] = pd.concat([a, b])
returns = pd.DataFrame(returns).T.astype(float)
# Out:
# HBox(children=(IntProgress(value=0, max=2748), HTML(value='')))

# %%
returns.head()
# Out:
#          RET_0     RET_1   RET_102  RET_105   RET_106   RET_108   RET_109  \
# 3316 -0.016501  0.018693  0.005316      NaN  0.001352  0.027374 -0.010890
# 3355  0.000674  0.005759  0.007938      NaN -0.005017 -0.007413 -0.005980
# 1662 -0.000919  0.010430  0.007901      NaN  0.006959  0.005593 -0.066666
# 3405 -0.004989  0.004558  0.004325      NaN -0.007720  0.002788 -0.038432
# 1602  0.002468 -0.024584  0.008947      NaN -0.004735 -0.031061  0.012366
#
#        RET_110   RET_114   RET_115  ...    RET_88     RET_9    RET_90  \
# 3316  0.057911  0.014155  0.021104  ...  0.027113  0.008602  0.018250
# 3355  0.011900 -0.011755  0.032401  ...  0.017933  0.001658  0.061274
# 1662  0.049822  0.021599  0.019816  ...  0.016645 -0.016289  0.027690
# 3405 -0.021308  0.000595  0.001613  ... -0.039065  0.021897 -0.031456
# 1602  0.045117 -0.015403 -0.015327  ... -0.028080  0.016530  0.019826
#
#         RET_91    RET_93    RET_95    RET_96    RET_97    RET_98    RET_99
# 3316  0.038581  0.027588  0.001251  0.037917 -0.002689  0.002140  0.023026
# 3355 -0.018643  0.000372 -0.010232 -0.013496  0.013819 -0.036501  0.017736
# 1662 -0.026479  0.006664  0.023721  0.013057 -0.008237  0.014655  0.011614
# 3405  0.029652  0.016171 -0.024835 -0.020391  0.006790  0.015796 -0.015763
# 1602  0.014627  0.010884 -0.025205  0.006157 -0.006526  0.002125  0.036186
#
# [5 rows x 200 columns]

# %% [markdown]
# ## Determine the best models
#
# For each target asset (liquid assets), we determine the best logit models.
# We first test the most significant feature, and then add them sequentially. At the end, we take the best AIC.

# %%
from sklearn.covariance import oas
features = returns.columns
cov = pd.DataFrame(oas(returns.fillna(0))[0], index=features, columns=features)

# %%
returns_corr = returns.corr()
returns_corr.head()
# Out:
#             RET_0     RET_1   RET_102   RET_105   RET_106   RET_108   RET_109  \
# RET_0    1.000000  0.178785  0.112833  0.146518  0.124386  0.089750  0.209515
# RET_1    0.178785  1.000000  0.102085  0.204024  0.112454  0.115006  0.185288
# RET_102  0.112833  0.102085  1.000000  0.187490  0.404844  0.202437  0.074562
# RET_105  0.146518  0.204024  0.187490  1.000000  0.181432  0.146691  0.135362
# RET_106  0.124386  0.112454  0.404844  0.181432  1.000000  0.142693  0.093292
#
#           RET_110   RET_114   RET_115  ...    RET_88     RET_9    RET_90  \
# RET_0    0.099405  0.176252  0.172117  ...  0.220032 -0.011212  0.188450
# RET_1    0.176570  0.217383  0.255642  ...  0.287438 -0.050225  0.241026
# RET_102  0.193401  0.101240  0.159988  ...  0.172473  0.009289  0.152705
# RET_105  0.250015  0.180981  0.225471  ...  0.216492 -0.003092  0.231410
# RET_106  0.176528  0.117702  0.171800  ...  0.170236 -0.018825  0.140980
#
#            RET_91    RET_93    RET_95    RET_96    RET_97    RET_98    RET_99
# RET_0    0.071751  0.198287  0.192124  0.061262  0.181465  0.098042  0.141503
# RET_1    0.099254  0.169832  0.231416  0.087668  0.173145  0.084043  0.155121
# RET_102  0.043701  0.115820  0.202409  0.034653  0.175302  0.445446  0.226669
# RET_105  0.179422  0.226487  0.214873  0.135527  0.237410  0.200838  0.246471
# RET_106  0.020384  0.164396  0.180597  0.012277  0.209689  0.403044  0.194298
#
# [5 rows x 200 columns]

# %%
import statsmodels.api as sm

target_regs = {}
for id_target in tqdm(target_ret_features):
    target_corr = returns_corr.loc[init_ret_features, id_target]
    target_corr = pd.DataFrame(target_corr).sort_values(by = id_target, ascending = False)
    na_days = list(returns[id_target][returns[id_target].isna()].index.values)
    target_scores = []
    for param_number in range(1,idx_ret_features.shape[0]+1):
        na_days = na_days + list(returns[target_corr.index[param_number-1]][returns[target_corr.index[param_number-1]].isna()].index.values)
        X = returns[target_corr.index[0:param_number]][~returns.index.isin(na_days)]
        Y = returns[id_target][~returns.index.isin(na_days)]
        Y = np.sign(Y)
        neg = Y[Y<0].index.values
        Y[neg] = 0
        model = sm.Logit(Y, X)
        reg = model.fit()
        target_scores.append(reg.aic)
    target_param_number = target_scores.index(min(target_scores))+1
    target_features = target_corr.index[0:target_param_number]
    na_days = list(returns[id_target][returns[id_target].isna()].index.values)
    for param_number in range(1,target_param_number+1):
        na_days = na_days + list(returns[target_corr.index[param_number-1]][returns[target_corr.index[param_number-1]].isna()].index.values)
    X = returns[target_features][~returns.index.isin(na_days)]
    Y = returns[id_target][~returns.index.isin(na_days)]
    Y = np.sign(Y)
    neg = Y[Y<0].index.values
    Y[neg] = 0
    target_model = sm.Logit(Y, X)
    target_reg = target_model.fit()
    target_regs[id_target] = [target_param_number, target_features, target_reg]
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# Optimization terminated successfully.
#          Current function value: 0.691965
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691229
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691054
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691021
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690810
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690465
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690352
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689811
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689277
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687852
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.687157
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.686388
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685625
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685610
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.686173
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.686144
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.686136
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.684147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683732
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682744
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682746
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682232
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.682871
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679098
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.679319
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.678820
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.679041
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679295
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680000
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679682
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679527
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676235
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674718
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674501
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.672535
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.670206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669074
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668536
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668831
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668712
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669430
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.668558
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.667602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663524
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664492
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.658156
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656963
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657654
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.655136
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.652175
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649457
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648788
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647236
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642257
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641946
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642547
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.639576
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.634990
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.634982
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635236
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.630949
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.628194
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626442
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.626718
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.619343
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.611455
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605431
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605187
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602399
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598879
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597527
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593180
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592918
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582505
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581742
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581738
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581255
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578609
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575675
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575635
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575121
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574001
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573721
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569608
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564602
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558764
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558642
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558222
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557654
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547253
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534162
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524202
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.523342
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.523374
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.502695
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.502678
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.501945
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.501649
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.691965
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.693123
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692624
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692150
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689528
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685833
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685911
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.685484
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.684844
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.683315
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.684373
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.681448
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.680098
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.679320
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.677059
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.676599
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.677075
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675763
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.675075
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.674981
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.672401
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664349
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663630
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661651
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.660303
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659668
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654914
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654137
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651606
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647382
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645850
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645875
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644010
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643794
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643646
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.637816
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.637065
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633994
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633808
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633077
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633251
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.632979
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631873
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.631394
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629693
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.627125
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626614
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625473
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625272
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.623817
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626640
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625395
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.625068
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614701
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614654
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.612218
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609034
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599425
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599834
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598416
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598157
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597744
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595899
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594685
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594964
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593983
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593826
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594021
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591845
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581293
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581242
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578466
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576160
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577583
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577831
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582072
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582070
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582063
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582043
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581156
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578199
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577873
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577848
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576808
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575262
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575027
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561682
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561682
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.549020
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548186
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548181
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540253
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540216
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538380
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537129
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524425
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.611508
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.610936
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.610360
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.610336
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609936
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613057
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613056
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604083
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.600452
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599058
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598108
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589291
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587675
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586636
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.584115
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.584045
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583958
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582190
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581706
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581631
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573095
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568781
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567074
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567029
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566048
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.560623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561215
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.560790
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556910
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557395
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557161
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557138
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556196
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.549579
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546789
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534595
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.532937
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517735
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.516572
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.515547
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.515270
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.513408
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.506994
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.506687
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.506346
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.506346
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.499911
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.495911
#          Iterations 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c99d1de09a43> in <module>
#      14         neg = Y[Y<0].index.values
#      15         Y[neg] = 0
# ---> 16         model = sm.Logit(Y, X)
#      17         reg = model.fit()
#      18         target_scores.append(reg.aic)
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, **kwargs)
#     427
#     428     def __init__(self, endog, exog, **kwargs):
# --> 429         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     430         if (not issubclass(self.__class__, MultinomialModel) and
#     431                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in __init__(self, endog, exog, **kwargs)
#     166     """
#     167     def __init__(self, endog, exog, **kwargs):
# --> 168         super(DiscreteModel, self).__init__(endog, exog, **kwargs)
#     169         self.raise_on_perfect_prediction = True
#     170
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     215     def __init__(self, endog, exog=None, **kwargs):
#     216         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
# --> 217         self.initialize()
#     218
#     219     def initialize(self):
#
# ~\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in initialize(self)
#     176         """
#     177         # assumes constant
# --> 178         rank = np.linalg.matrix_rank(self.exog)
#     179         self.df_model = float(rank - 1)
#     180         self.df_resid = float(self.exog.shape[0] - rank)
#
# <__array_function__ internals> in matrix_rank(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in matrix_rank(M, tol, hermitian)
#    1900     if M.ndim < 2:
#    1901         return int(not all(M==0))
# -> 1902     S = svd(M, compute_uv=False, hermitian=hermitian)
#    1903     if tol is None:
#    1904         tol = S.max(axis=-1, keepdims=True) * max(M.shape[-2:]) * finfo(S.dtype).eps
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1672         signature = 'D->d' if isComplexType(t) else 'd->d'
#    1673         s = gufunc(a, signature=signature, extobj=extobj)
# -> 1674         s = s.astype(_realType(result_t), copy=False)
#    1675         return s
#    1676
#
# KeyboardInterrupt:

# %%
target_regs

# %% [markdown]
# ## Prediction on test data
#
# We thus simply make the predictions on the test data set using the models.
#
# If there is missing values, we use the iterative imputer from sklearn

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp_mean = IterativeImputer()
imp_mean.fit(X = X_train)

# %%
pred = {}
NA_count = 0
for idx, row in tqdm(X_test.iterrows()):
    id_target = 'RET_' + str(int(row['ID_TARGET']))
    target_param_number, target_features, target_reg = target_regs[id_target]
    row_fill = pd.DataFrame(imp_mean.transform(np.matrix(row)))
    row_fill.columns = row.index
    X = row_fill[target_features]
    res = 0
    if np.isnan(X).values.any():
        res = np.sign(returns[id_target].mean())
        NA_count += 1
    else:
        res = np.sign(target_reg.predict(np.matrix(X))-0.5)[0]
    pred[idx] = res
pred = pd.Series(pred, name="RET_TARGET")

# %%
NA_count

# %% [markdown]
# ## Save the result before submission

# %%
pred.name = "RET_TARGET"
pred.index.name = 'ID'
pred = pred.astype(int)
pred.to_csv('../ChallengeDataQRT2021Data/logit.csv', header = True)
